# %% [markdown]
# # Batch OCR Processing for ZANT
# Przetwarza wszystkie PDF z katalogu data/ używając Azure Document Intelligence

# %%
# !pip install azure-ai-documentintelligence python-dotenv
# Out:
# Requirement already satisfied: azure-ai-documentintelligence in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (1.0.2)
# Requirement already satisfied: python-dotenv in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: isodate>=0.6.1 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from azure-ai-documentintelligence) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from azure-ai-documentintelligence) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from azure-ai-documentintelligence) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-documentintelligence) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/muhammad/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (2025.11.12)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from pathlib import Path
import json
# from pathlib import Path
import asyncio
from dotenv import load_dotenv
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence.aio import DocumentIntelligenceClient

load_dotenv()

endpoint = os.getenv('AZURE_DOCUMENT_INTELLIGENCE_ENDPOINT')
key = os.getenv('AZURE_DOCUMENT_INTELLIGENCE_KEY')

print(f"Endpoint: {endpoint[:50]}...")
print(f"Key: {'SET' if key else 'MISSING'}")
# Out:
# Endpoint: https://di-zus-digital-support.cognitiveservices.a...
# Key: SET

# %%
def get_files_by_dir(base_path: str | Path) -> dict[str, list[str]]:
    """Skanuje katalogi i zwraca slownik katalog -> lista plikow"""
    result = {}
    base_path = Path(base_path)
    
    for root, dirs, files in os.walk(base_path, followlinks=False):
        if files:
            result[root] = files[:]
            
    return result


def make_out_path(src_path: str | Path, out_dir: str | Path = "out", base_dir: str | Path = "data") -> Path:
    """Tworzy sciezke wyjsciowa zachowujac strukture"""
    src_path = Path(src_path)
    out_dir = Path(out_dir)
    base_dir = Path(base_dir)
    
    try:
        rel = src_path.relative_to(base_dir)
    except ValueError:
        rel = src_path.name
    
    out_path = out_dir / rel.with_suffix(rel.suffix + ".json")
    out_path.parent.mkdir(parents=True, exist_ok=True)
    
    return out_path

# %%
async def analyze_single_pdf(file_path: str) -> dict:
    """Analizuje pojedynczy PDF"""
    client = DocumentIntelligenceClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(key),
    )
    
    try:
        async with client:
            with open(file_path, 'rb') as f:
                poller = await client.begin_analyze_document(
                    "prebuilt-read",
                    f.read(),
                    content_type="application/pdf"
                )
                result = await poller.result()
                return result
    except Exception as e:
        print(f"Error analyzing {file_path}: {e}")
        return None

# %%
async def process_one(path: str, out_dir: Path, results: dict):
    """Przetwarza jeden plik"""
    if path in results:
        return
    
    print(f"Processing: {path}")
    
    result = await analyze_single_pdf(path)
    
    if result is None:
        return
    
    # Ekstraktuj dane
    data = {
        "file_path": path,
        "content": result.content if hasattr(result, 'content') else "",
        "page_count": len(result.pages) if hasattr(result, 'pages') else 0,
    }
    
    # Zapisz
    out_path = make_out_path(path, out_dir)
    
    with open(out_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    
    results[path] = str(out_path)
    print(f"Saved: {out_path}")

# %%
async def process_many(files_by_dir: dict, out_dir: str = "out", max_concurrency: int = 5):
    """Przetwarza wiele plikow z ograniczeniem wspolbieznosci"""
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)
    
    results = {}
    sem = asyncio.Semaphore(max_concurrency)
    
    async def _wrapped(path: str):
        async with sem:
            await process_one(path, out_dir, results)
    
    # Zbierz wszystkie sciezki
    all_paths = []
    for dir_path, filenames in files_by_dir.items():
        base = Path(dir_path)
        for name in filenames:
            if name.endswith('.pdf'):
                all_paths.append(str(base / name))
    
    print(f"Found {len(all_paths)} PDF files")
    
    # Uruchom
    tasks = [asyncio.create_task(_wrapped(p)) for p in all_paths]
    await asyncio.gather(*tasks, return_exceptions=True)
    
    print(f"\nCompleted: {len(results)}/{len(all_paths)} files")
    return results

# %%
# Skanuj pliki
base_dir = "data"
files_by_dir = get_files_by_dir(base_dir)

print(f"Found {len(files_by_dir)} directories")
for dir_path, files in list(files_by_dir.items())[:5]:
    print(f"  {dir_path}: {len(files)} files")
# Out:
# Found 111 directories
#   data/wypadek 20: 4 files
#   data/wypadek 66: 4 files
#   data/wypadek 28: 4 files
#   data/wypadek 30: 4 files
#   data/wypadek 23: 4 files

# %%
# Uruchom przetwarzanie
results = await process_many(
    files_by_dir=files_by_dir,
    out_dir="out",
    max_concurrency=5
)
# Out:
# Found 445 PDF files
# Processing: data/wypadek 20/wyjaśnienia poszkodowanego 20.pdf
# Processing: data/wypadek 20/opinia 20.pdf
# Processing: data/wypadek 20/zawiadomienie o wypadku 20.pdf
# Processing: data/wypadek 20/karta wypadku 20.pdf
# Processing: data/wypadek 66/Zawiadomienie o wypadku 66.pdf
# Saved: out/wypadek 20/opinia 20.pdf.json
# Processing: data/wypadek 66/Wyjaśnienia poszkodowanego 66.pdf
# Saved: out/wypadek 20/karta wypadku 20.pdf.json
# Processing: data/wypadek 66/Opinia 66.pdf
# Saved: out/wypadek 20/wyjaśnienia poszkodowanego 20.pdf.json
# Processing: data/wypadek 66/Karta wypadku 66.pdf
# Saved: out/wypadek 20/zawiadomienie o wypadku 20.pdf.json
# Processing: data/wypadek 28/zawiadomienie o wypadku 28.pdf
# Saved: out/wypadek 66/Zawiadomienie o wypadku 66.pdf.json
# Processing: data/wypadek 28/opinia 28.pdf
# Saved: out/wypadek 66/Opinia 66.pdf.json
# Processing: data/wypadek 28/wyjaśnienia poszkodowanego 28.pdf
# Saved: out/wypadek 66/Karta wypadku 66.pdf.json
# Processing: data/wypadek 28/karta wypadku 28.pdf
# Saved: out/wypadek 66/Wyjaśnienia poszkodowanego 66.pdf.json
# Processing: data/wypadek 30/wyjaśnienia poszkodowanego 30.pdf
# Saved: out/wypadek 28/opinia 28.pdf.json
# Processing: data/wypadek 30/opinia 30.pdf
# Saved: out/wypadek 28/zawiadomienie o wypadku 28.pdf.json
# Processing: data/wypadek 30/karta wypadku 30.pdf
# Saved: out/wypadek 28/wyjaśnienia poszkodowanego 28.pdf.json
# Processing: data/wypadek 30/zawiadomienie o wypadku 30.pdf
# Saved: out/wypadek 28/karta wypadku 28.pdf.json
# Processing: data/wypadek 23/wyjaśnienia poszkodowanego 23.pdf
# Saved: out/wypadek 30/wyjaśnienia poszkodowanego 30.pdf.json
# Processing: data/wypadek 23/opinia 23.pdf
# Saved: out/wypadek 30/opinia 30.pdf.json
# Processing: data/wypadek 23/karta wypadku 23.pdf
# Saved: out/wypadek 30/karta wypadku 30.pdf.json
# Processing: data/wypadek 23/zawiadomienie o wypadku 23.pdf
# Saved: out/wypadek 30/zawiadomienie o wypadku 30.pdf.json
# Processing: data/wypadek 51/opinia 51.pdf
# Saved: out/wypadek 23/opinia 23.pdf.json
# Processing: data/wypadek 51/wyjaśnienia poszkodowanego 51.pdf
# Saved: out/wypadek 23/wyjaśnienia poszkodowanego 23.pdf.json
# Processing: data/wypadek 51/zawiadomienie o wypadku 51.pdf
# Saved: out/wypadek 23/karta wypadku 23.pdf.json
# Processing: data/wypadek 51/karta wypadku 51.pdf
# Saved: out/wypadek 23/zawiadomienie o wypadku 23.pdf.json
# Processing: data/wypadek 48/karta wypadku 48.pdf
# Saved: out/wypadek 51/wyjaśnienia poszkodowanego 51.pdf.json
# Processing: data/wypadek 48/opinia 48.pdf
# Saved: out/wypadek 51/zawiadomienie o wypadku 51.pdf.json
# Processing: data/wypadek 48/zawiadomienie o wypadku 48.pdf
# Saved: out/wypadek 51/opinia 51.pdf.json
# Processing: data/wypadek 48/wyjaśnienia poszkodowanego 48.pdf
# Saved: out/wypadek 51/karta wypadku 51.pdf.json
# Processing: data/wypadek 110/karta wypadku 110.pdf
# Saved: out/wypadek 48/karta wypadku 48.pdf.json
# Processing: data/wypadek 110/opinia w sprawie prawnej kwalifikacji wypadku 110.pdf
# Saved: out/wypadek 48/opinia 48.pdf.json
# Processing: data/wypadek 110/zapis wyjaśnień poszkodowanego 110.pdf
# Saved: out/wypadek 48/zawiadomienie o wypadku 48.pdf.json
# Processing: data/wypadek 110/zawiadomienie o wypadku 110.pdf
# Saved: out/wypadek 110/karta wypadku 110.pdf.json
# Processing: data/wypadek 14/karta wypadku 14.pdf
# Saved: out/wypadek 48/wyjaśnienia poszkodowanego 48.pdf.json
# Processing: data/wypadek 14/zapis wyjaśnień poszkodowanego 14.pdf
# Saved: out/wypadek 110/opinia w sprawie prawnej kwalifikacji wypadku 110.pdf.json
# Processing: data/wypadek 14/opinia 14.pdf
# Saved: out/wypadek 110/zawiadomienie o wypadku 110.pdf.json
# Processing: data/wypadek 14/zawiadomienie o wypadku 14.pdf
# Saved: out/wypadek 14/karta wypadku 14.pdf.json
# Processing: data/wypadek 2/zawiadomienie o wypadku 2.pdf
# Saved: out/wypadek 110/zapis wyjaśnień poszkodowanego 110.pdf.json
# Processing: data/wypadek 2/opinia  2.pdf
# Saved: out/wypadek 14/zapis wyjaśnień poszkodowanego 14.pdf.json
# Processing: data/wypadek 2/karta wypadku 2.pdf
# Saved: out/wypadek 14/opinia 14.pdf.json
# Processing: data/wypadek 2/zapis wyjaśnień poszkodowanego 2.pdf
# Saved: out/wypadek 2/opinia  2.pdf.json
# Processing: data/wypadek 58/opinia 58.pdf
# Saved: out/wypadek 2/karta wypadku 2.pdf.json
# Processing: data/wypadek 58/wyjaśnienia poszkodowanego 58.pdf
# Saved: out/wypadek 2/zawiadomienie o wypadku 2.pdf.json
# Processing: data/wypadek 58/zawiadomienie o wypadku 58.pdf
# Saved: out/wypadek 14/zawiadomienie o wypadku 14.pdf.json
# Processing: data/wypadek 58/karta wypadku 58.pdf
# Saved: out/wypadek 2/zapis wyjaśnień poszkodowanego 2.pdf.json
# Processing: data/wypadek 106/zawiadomienie o wypadku 106.pdf
# Saved: out/wypadek 58/opinia 58.pdf.json
# Processing: data/wypadek 106/opinia 106.pdf
# Saved: out/wypadek 58/wyjaśnienia poszkodowanego 58.pdf.json
# Processing: data/wypadek 106/karta wypadku 106.pdf
# Saved: out/wypadek 58/zawiadomienie o wypadku 58.pdf.json
# Processing: data/wypadek 106/wyjaśnienia poszkodowanego 106.pdf
# Saved: out/wypadek 58/karta wypadku 58.pdf.json
# Processing: data/wypadek 40/opinia 40.pdf
# Saved: out/wypadek 106/zawiadomienie o wypadku 106.pdf.json
# Processing: data/wypadek 40/wyjaśnienia poszkodowanego 40.pdf
# Saved: out/wypadek 106/opinia 106.pdf.json
# Processing: data/wypadek 40/zawiadomienie o wypadku 40.pdf
# Saved: out/wypadek 106/karta wypadku 106.pdf.json
# Processing: data/wypadek 40/karta wypadku 40.pdf
# Saved: out/wypadek 106/wyjaśnienia poszkodowanego 106.pdf.json
# Processing: data/wypadek 94/zawiadomienie o wypadku 94.pdf
# Saved: out/wypadek 40/opinia 40.pdf.json
# Processing: data/wypadek 94/karta wypadku 94.pdf
# Saved: out/wypadek 40/wyjaśnienia poszkodowanego 40.pdf.json
# Processing: data/wypadek 94/opinia 94.pdf
# Saved: out/wypadek 40/zawiadomienie o wypadku 40.pdf.json
# Processing: data/wypadek 94/wyjaśnienia poszkodowanego 94.pdf
# Saved: out/wypadek 40/karta wypadku 40.pdf.json
# Processing: data/wypadek 46/wyjaśnienia poszkodowanego 46.pdf
# Saved: out/wypadek 94/zawiadomienie o wypadku 94.pdf.json
# Processing: data/wypadek 46/karta wypadku 46.pdf
# Saved: out/wypadek 94/karta wypadku 94.pdf.json
# Processing: data/wypadek 46/opinia 46.pdf
# Saved: out/wypadek 94/opinia 94.pdf.json
# Processing: data/wypadek 46/zawiadomienie o wypadku 46.pdf
# Saved: out/wypadek 94/wyjaśnienia poszkodowanego 94.pdf.json
# Processing: data/wypadek 93/zawiadomienie o wypadku 93.pdf
# Saved: out/wypadek 46/opinia 46.pdf.json
# Processing: data/wypadek 93/wyjaśnienia poszkodowanego 93.pdf
# Saved: out/wypadek 46/karta wypadku 46.pdf.json
# Processing: data/wypadek 93/opinia 93.pdf
# Saved: out/wypadek 46/wyjaśnienia poszkodowanego 46.pdf.json
# Processing: data/wypadek 93/karta wypadku 93.pdf
# Saved: out/wypadek 93/wyjaśnienia poszkodowanego 93.pdf.json
# Processing: data/wypadek 111/zawiadomienie o wypadku 111.pdf
# Saved: out/wypadek 93/zawiadomienie o wypadku 93.pdf.json
# Processing: data/wypadek 111/zapis wyjaśnień poszkodowanego 111.pdf
# Saved: out/wypadek 46/zawiadomienie o wypadku 46.pdf.json
# Processing: data/wypadek 111/opinia w sprawie prawnej kwalifikacji wypadku 111.pdf
# Saved: out/wypadek 93/opinia 93.pdf.json
# Processing: data/wypadek 111/karta wypadku 111.pdf
# Saved: out/wypadek 93/karta wypadku 93.pdf.json
# Processing: data/wypadek 69/Zawiadomienie o wypadku 69.pdf
# Saved: out/wypadek 111/zapis wyjaśnień poszkodowanego 111.pdf.json
# Processing: data/wypadek 69/KARTA WYPADKU 69.pdf
# Saved: out/wypadek 111/karta wypadku 111.pdf.json
# Processing: data/wypadek 69/WYJASNIENIA POSZKODOWANEGO 69.pdf
# Saved: out/wypadek 111/opinia w sprawie prawnej kwalifikacji wypadku 111.pdf.json
# Processing: data/wypadek 69/OPINIA 69.pdf
# Saved: out/wypadek 111/zawiadomienie o wypadku 111.pdf.json
# Processing: data/wypadek 97/karta wypadku 97.pdf
# Saved: out/wypadek 69/Zawiadomienie o wypadku 69.pdf.json
# Processing: data/wypadek 97/zawiadomienie o wypadku 97.pdf
# Saved: out/wypadek 69/KARTA WYPADKU 69.pdf.json
# Processing: data/wypadek 97/wyjaśnienia poszkodowanego 97.pdf
# Saved: out/wypadek 69/OPINIA 69.pdf.json
# Processing: data/wypadek 97/opinia 97.pdf
# Saved: out/wypadek 69/WYJASNIENIA POSZKODOWANEGO 69.pdf.json
# Processing: data/wypadek 36/opinia 36.pdf
# Saved: out/wypadek 97/karta wypadku 97.pdf.json
# Processing: data/wypadek 36/wyjaśnienia poszkodowanego 36.pdf
# Saved: out/wypadek 97/zawiadomienie o wypadku 97.pdf.json
# Processing: data/wypadek 36/zawiadomienie o wypadku 36.pdf
# Saved: out/wypadek 97/wyjaśnienia poszkodowanego 97.pdf.json
# Processing: data/wypadek 36/karta wypadku 36.pdf
# Saved: out/wypadek 97/opinia 97.pdf.json
# Processing: data/wypadek 75/Zawiadomienie o wypadku 75.pdf
# Saved: out/wypadek 36/opinia 36.pdf.json
# Processing: data/wypadek 75/KARTA WYPADKU 75.pdf
# Saved: out/wypadek 36/wyjaśnienia poszkodowanego 36.pdf.json
# Processing: data/wypadek 75/WYJAŚNIENIA POSZKODOWANEGO 75.pdf
# Saved: out/wypadek 36/zawiadomienie o wypadku 36.pdf.json
# Processing: data/wypadek 75/OPINIA 75.pdf
# Saved: out/wypadek 36/karta wypadku 36.pdf.json
# Processing: data/wypadek 84/karta wypadku 84.pdf
# Saved: out/wypadek 75/KARTA WYPADKU 75.pdf.json
# Processing: data/wypadek 84/opinia 84.pdf
# Saved: out/wypadek 75/Zawiadomienie o wypadku 75.pdf.json
# Processing: data/wypadek 84/wyjaśnienia poszkodowanego 84.pdf
# Saved: out/wypadek 75/WYJAŚNIENIA POSZKODOWANEGO 75.pdf.json
# Processing: data/wypadek 84/zawiadomienie o wypadku 84.pdf
# Saved: out/wypadek 75/OPINIA 75.pdf.json
# Processing: data/wypadek 100/opinia 100.pdf
# Saved: out/wypadek 84/karta wypadku 84.pdf.json
# Processing: data/wypadek 100/zawiadomienie o wypadku 100.pdf
# Saved: out/wypadek 84/opinia 84.pdf.json
# Processing: data/wypadek 100/wyjaśnienia poszkodowanego 100.pdf
# Saved: out/wypadek 84/wyjaśnienia poszkodowanego 84.pdf.json
# Processing: data/wypadek 100/karta wypadku 100.pdf
# Saved: out/wypadek 84/zawiadomienie o wypadku 84.pdf.json
# Processing: data/wypadek 99/wyjaśnienia poszkodowanego 99.pdf
# Saved: out/wypadek 100/opinia 100.pdf.json
# Processing: data/wypadek 99/karta wypadku 99.pdf
# Saved: out/wypadek 100/zawiadomienie o wypadku 100.pdf.json
# Processing: data/wypadek 99/zawiadomienie o wypadku 99.pdf
# Saved: out/wypadek 100/karta wypadku 100.pdf.json
# Processing: data/wypadek 99/opinia 99.pdf
# Saved: out/wypadek 100/wyjaśnienia poszkodowanego 100.pdf.json
# Processing: data/wypadek 19/karta wypadku 19.pdf
# Saved: out/wypadek 99/wyjaśnienia poszkodowanego 99.pdf.json
# Processing: data/wypadek 19/opinia 19.pdf
# Saved: out/wypadek 99/karta wypadku 99.pdf.json
# Processing: data/wypadek 19/zawiadomienie o wypadku 19.pdf
# Saved: out/wypadek 99/zawiadomienie o wypadku 99.pdf.json
# Processing: data/wypadek 19/wyjaśnienia poszkodowanego 19.pdf
# Saved: out/wypadek 99/opinia 99.pdf.json
# Processing: data/wypadek 80/wyjaśnienie poszkodowanego 80.pdf
# Saved: out/wypadek 19/karta wypadku 19.pdf.json
# Processing: data/wypadek 80/karta wypadku 80.pdf
# Saved: out/wypadek 19/opinia 19.pdf.json
# Processing: data/wypadek 80/opinia 80.pdf
# Saved: out/wypadek 19/wyjaśnienia poszkodowanego 19.pdf.json
# Processing: data/wypadek 80/zawiadomienie o wypadku 80.pdf
# Saved: out/wypadek 19/zawiadomienie o wypadku 19.pdf.json
# Processing: data/wypadek 85/karta wypadku 85.pdf
# Saved: out/wypadek 80/wyjaśnienie poszkodowanego 80.pdf.json
# Processing: data/wypadek 85/wyjaśnienia poszkodowanego 85.pdf
# Saved: out/wypadek 80/opinia 80.pdf.json
# Processing: data/wypadek 85/zawiadomienie o wypadku 85.pdf
# Saved: out/wypadek 80/karta wypadku 80.pdf.json
# Processing: data/wypadek 85/opinia 85.pdf
# Saved: out/wypadek 85/karta wypadku 85.pdf.json
# Processing: data/wypadek 89/karta wypadku 89.pdf
# Saved: out/wypadek 80/zawiadomienie o wypadku 80.pdf.json
# Processing: data/wypadek 89/wyjaśnienia poszkodowanego 89.pdf
# Saved: out/wypadek 85/wyjaśnienia poszkodowanego 85.pdf.json
# Processing: data/wypadek 89/opinia 89.pdf
# Saved: out/wypadek 85/zawiadomienie o wypadku 85.pdf.json
# Processing: data/wypadek 89/zawiadomienie o wypadku 89.pdf
# Saved: out/wypadek 85/opinia 85.pdf.json
# Processing: data/wypadek 78/zawiadomienie o wypadku 78.pdf
# Saved: out/wypadek 89/karta wypadku 89.pdf.json
# Processing: data/wypadek 78/wyjaśnienie poszkodowanego 78.pdf
# Saved: out/wypadek 89/wyjaśnienia poszkodowanego 89.pdf.json
# Processing: data/wypadek 78/karta wypadku 78.pdf
# Saved: out/wypadek 89/opinia 89.pdf.json
# Processing: data/wypadek 78/opinia 78.pdf
# Saved: out/wypadek 89/zawiadomienie o wypadku 89.pdf.json
# Processing: data/wypadek 31/wyjaśnienia poszkodowanego 31.pdf
# Saved: out/wypadek 78/zawiadomienie o wypadku 78.pdf.json
# Processing: data/wypadek 31/opinia 31.pdf
# Saved: out/wypadek 78/wyjaśnienie poszkodowanego 78.pdf.json
# Processing: data/wypadek 31/zawiadomienie o wypadku 31.pdf
# Saved: out/wypadek 78/karta wypadku 78.pdf.json
# Processing: data/wypadek 31/karta wypadku 31.pdf
# Saved: out/wypadek 78/opinia 78.pdf.json
# Processing: data/wypadek 52/opinia 52.pdf
# Saved: out/wypadek 31/wyjaśnienia poszkodowanego 31.pdf.json
# Processing: data/wypadek 52/zawiadomienie o wypadku 52.pdf
# Saved: out/wypadek 31/opinia 31.pdf.json
# Processing: data/wypadek 52/wyjaśnienia poszkodowanego 52.pdf
# Saved: out/wypadek 31/zawiadomienie o wypadku 31.pdf.json
# Processing: data/wypadek 52/karta wypadku 52.pdf
# Saved: out/wypadek 31/karta wypadku 31.pdf.json
# Processing: data/wypadek 109/zawiadomienie o wypadku 109.pdf
# Saved: out/wypadek 52/opinia 52.pdf.json
# Processing: data/wypadek 109/zapis wyjaśnień poszkodowanego 109.pdf
# Saved: out/wypadek 52/zawiadomienie o wypadku 52.pdf.json
# Processing: data/wypadek 109/opinia w spawie prawnej kwalifikacji wypadku 109.pdf
# Saved: out/wypadek 52/wyjaśnienia poszkodowanego 52.pdf.json
# Processing: data/wypadek 109/karta wypadku 109.pdf
# Saved: out/wypadek 52/karta wypadku 52.pdf.json
# Processing: data/wypadek 68/Zawiadomienie o wypadku 68.pdf
# Saved: out/wypadek 109/zawiadomienie o wypadku 109.pdf.json
# Processing: data/wypadek 68/WYJAŚNIENIA POSZKODOWANEGO 68.pdf
# Saved: out/wypadek 109/zapis wyjaśnień poszkodowanego 109.pdf.json
# Processing: data/wypadek 68/OPINIA 68.pdf
# Saved: out/wypadek 109/opinia w spawie prawnej kwalifikacji wypadku 109.pdf.json
# Processing: data/wypadek 68/KARTA WYPADKU 68.pdf
# Saved: out/wypadek 109/karta wypadku 109.pdf.json
# Processing: data/wypadek 56/opinia 56.pdf
# Saved: out/wypadek 68/WYJAŚNIENIA POSZKODOWANEGO 68.pdf.json
# Processing: data/wypadek 56/wyjaśnienia oszkodowanego 56.pdf
# Saved: out/wypadek 68/Zawiadomienie o wypadku 68.pdf.json
# Processing: data/wypadek 56/karta wyadku 56.pdf
# Saved: out/wypadek 68/OPINIA 68.pdf.json
# Processing: data/wypadek 56/zawiadomienie o wypadku 56.pdf
# Saved: out/wypadek 68/KARTA WYPADKU 68.pdf.json
# Processing: data/wypadek 101/opinia 101.pdf
# Saved: out/wypadek 56/opinia 56.pdf.json
# Processing: data/wypadek 101/karta wypadku 101.pdf
# Saved: out/wypadek 56/wyjaśnienia oszkodowanego 56.pdf.json
# Processing: data/wypadek 101/zawiadomienie o wypadku 101.pdf
# Saved: out/wypadek 56/karta wyadku 56.pdf.json
# Processing: data/wypadek 101/wyjaśnienia poszkodowanego 101.pdf
# Saved: out/wypadek 56/zawiadomienie o wypadku 56.pdf.json
# Processing: data/wypadek 24/opinia 24.pdf
# Saved: out/wypadek 101/opinia 101.pdf.json
# Processing: data/wypadek 24/karta wypadku 24.pdf
# Saved: out/wypadek 101/karta wypadku 101.pdf.json
# Processing: data/wypadek 24/wyjaśnienia poszkodowanego 24.pdf
# Saved: out/wypadek 101/wyjaśnienia poszkodowanego 101.pdf.json
# Processing: data/wypadek 24/zawiadomienie o wypadku 24.pdf
# Saved: out/wypadek 101/zawiadomienie o wypadku 101.pdf.json
# Processing: data/wypadek 74/Zawiadomienie o wypadku 74.pdf
# Saved: out/wypadek 24/opinia 24.pdf.json
# Processing: data/wypadek 74/KARTA WYPADKU 74.pdf
# Saved: out/wypadek 24/karta wypadku 24.pdf.json
# Processing: data/wypadek 74/OPINIA 74.pdf
# Saved: out/wypadek 24/wyjaśnienia poszkodowanego 24.pdf.json
# Processing: data/wypadek 74/WYJAŚNIENIA POSZKODOWANEGO 74.pdf
# Saved: out/wypadek 74/KARTA WYPADKU 74.pdf.json
# Processing: data/wypadek 90/wyjaśnienia poszkodowanego 90.pdf
# Saved: out/wypadek 24/zawiadomienie o wypadku 24.pdf.json
# Processing: data/wypadek 90/zawiadomienie o wypadku 90.pdf
# Saved: out/wypadek 74/Zawiadomienie o wypadku 74.pdf.json
# Processing: data/wypadek 90/opinia 90.pdf
# Saved: out/wypadek 74/OPINIA 74.pdf.json
# Processing: data/wypadek 90/karta wypadku 90.pdf
# Saved: out/wypadek 74/WYJAŚNIENIA POSZKODOWANEGO 74.pdf.json
# Processing: data/wypadek 45/zawiadomienie o wypadku 45.pdf
# Saved: out/wypadek 90/wyjaśnienia poszkodowanego 90.pdf.json
# Processing: data/wypadek 45/wyjaśnienia poszkodowanego 45.pdf
# Saved: out/wypadek 90/zawiadomienie o wypadku 90.pdf.json
# Processing: data/wypadek 45/karta wypadku 45.pdf
# Saved: out/wypadek 90/opinia 90.pdf.json
# Processing: data/wypadek 45/opinia 45.pdf
# Saved: out/wypadek 90/karta wypadku 90.pdf.json
# Processing: data/wypadek 38/opinia 38.pdf
# Saved: out/wypadek 45/zawiadomienie o wypadku 45.pdf.json
# Processing: data/wypadek 38/wyjaśnienia poszkodowanego 38.pdf
# Saved: out/wypadek 45/wyjaśnienia poszkodowanego 45.pdf.json
# Processing: data/wypadek 38/karta wypadku 38.pdf
# Saved: out/wypadek 38/opinia 38.pdf.json
# Processing: data/wypadek 38/zawiadomienie o wypadku 38.pdf
# Saved: out/wypadek 38/wyjaśnienia poszkodowanego 38.pdf.json
# Processing: data/wypadek 103/karta wypadku 103.pdf
# Saved: out/wypadek 38/karta wypadku 38.pdf.json
# Processing: data/wypadek 103/wyjaśnienia poszkodowanego 103.pdf
# Saved: out/wypadek 45/karta wypadku 45.pdf.json
# Processing: data/wypadek 103/opinia 103.pdf
# Saved: out/wypadek 38/zawiadomienie o wypadku 38.pdf.json
# Processing: data/wypadek 103/zawiadomienie o wypadku 103.pdf
# Saved: out/wypadek 45/opinia 45.pdf.json
# Processing: data/wypadek 5/zawiadomienie o wypadku 5.pdf
# Saved: out/wypadek 103/karta wypadku 103.pdf.json
# Processing: data/wypadek 5/karta wypadku 5.pdf
# Saved: out/wypadek 103/wyjaśnienia poszkodowanego 103.pdf.json
# Processing: data/wypadek 5/wyjaśnienia poszkodowanego 5.pdf
# Saved: out/wypadek 103/opinia 103.pdf.json
# Processing: data/wypadek 5/opinia 5.pdf
# Saved: out/wypadek 5/zawiadomienie o wypadku 5.pdf.json
# Processing: data/wypadek 33/zawiadomienie o wypadku 33.pdf
# Saved: out/wypadek 5/karta wypadku 5.pdf.json
# Processing: data/wypadek 33/wyjaśnienia poszkodowanego 33.pdf
# Saved: out/wypadek 103/zawiadomienie o wypadku 103.pdf.json
# Processing: data/wypadek 33/karta wypadku 33.pdf
# Saved: out/wypadek 5/wyjaśnienia poszkodowanego 5.pdf.json
# Processing: data/wypadek 33/opinia 33.pdf
# Saved: out/wypadek 5/opinia 5.pdf.json
# Processing: data/wypadek 6/karta wypadku 6.pdf
# Saved: out/wypadek 33/opinia 33.pdf.json
# Processing: data/wypadek 6/zawiadomienie o wypadku 6.pdf
# Saved: out/wypadek 33/karta wypadku 33.pdf.json
# Processing: data/wypadek 6/wyjaśnienia poszkodowanego 6.pdf
# Saved: out/wypadek 33/wyjaśnienia poszkodowanego 33.pdf.json
# Processing: data/wypadek 6/opinia 6.pdf
# Saved: out/wypadek 33/zawiadomienie o wypadku 33.pdf.json
# Processing: data/wypadek 95/wyjaśnienia poszkodowanego 95.pdf
# Saved: out/wypadek 6/karta wypadku 6.pdf.json
# Processing: data/wypadek 95/opinia 95.pdf
# Saved: out/wypadek 6/zawiadomienie o wypadku 6.pdf.json
# Processing: data/wypadek 95/zawiadomienie o wypadku 95.pdf
# Saved: out/wypadek 6/wyjaśnienia poszkodowanego 6.pdf.json
# Processing: data/wypadek 95/karta wypadku 95.pdf
# Saved: out/wypadek 6/opinia 6.pdf.json
# Saved: out/wypadek 95/wyjaśnienia poszkodowanego 95.pdf.json
# Processing: data/wypadek 37/karta wypadku 37.pdf
# Processing: data/wypadek 37/zawiadomienie o wypadku 37.pdf
# Saved: out/wypadek 95/opinia 95.pdf.json
# Processing: data/wypadek 37/opinia 37.pdf
# Saved: out/wypadek 95/zawiadomienie o wypadku 95.pdf.json
# Processing: data/wypadek 37/wyjaśnienia poszkodowanego 37.pdf
# Saved: out/wypadek 95/karta wypadku 95.pdf.json
# Processing: data/wypadek 22/zawiadomienie o wypadku 22.pdf
# Saved: out/wypadek 37/karta wypadku 37.pdf.json
# Processing: data/wypadek 22/opinia 22.pdf
# Saved: out/wypadek 37/zawiadomienie o wypadku 37.pdf.json
# Processing: data/wypadek 22/wyjaśnienia  poszkodowanego 22.pdf
# Saved: out/wypadek 37/opinia 37.pdf.json
# Processing: data/wypadek 22/karta wypadku 22.pdf
# Saved: out/wypadek 37/wyjaśnienia poszkodowanego 37.pdf.json
# Processing: data/wypadek 59/opinia 59.pdf
# Saved: out/wypadek 22/opinia 22.pdf.json
# Processing: data/wypadek 59/karta wypadku 59.pdf
# Saved: out/wypadek 22/zawiadomienie o wypadku 22.pdf.json
# Processing: data/wypadek 59/zawiadomienie o wypadku 59.pdf
# Saved: out/wypadek 22/wyjaśnienia  poszkodowanego 22.pdf.json
# Processing: data/wypadek 59/wyjaśnienia poszkodowanego 59.pdf
# Saved: out/wypadek 22/karta wypadku 22.pdf.json
# Processing: data/wypadek 102/wyjaśnienia poszkodowanego 102.pdf
# Saved: out/wypadek 59/opinia 59.pdf.json
# Processing: data/wypadek 102/zawiadomienie o wypadku 102.pdf
# Saved: out/wypadek 59/karta wypadku 59.pdf.json
# Processing: data/wypadek 102/karta wypadku 102.pdf
# Saved: out/wypadek 59/zawiadomienie o wypadku 59.pdf.json
# Processing: data/wypadek 102/opinia 102.pdf
# Saved: out/wypadek 59/wyjaśnienia poszkodowanego 59.pdf.json
# Processing: data/wypadek 73/Zawiadomienie o wypadku 73.pdf
# Saved: out/wypadek 102/wyjaśnienia poszkodowanego 102.pdf.json
# Processing: data/wypadek 73/OPINIA 73.pdf
# Saved: out/wypadek 102/karta wypadku 102.pdf.json
# Processing: data/wypadek 73/KARTA WYPADKU 73.pdf
# Saved: out/wypadek 102/zawiadomienie o wypadku 102.pdf.json
# Processing: data/wypadek 73/WYJAŚNIENIA POSZKODOWANEGO 73.pdf
# Saved: out/wypadek 102/opinia 102.pdf.json
# Processing: data/wypadek 79/karta wypadku 79.pdf
# Saved: out/wypadek 73/OPINIA 73.pdf.json
# Processing: data/wypadek 79/zawiadomienie o wypadku 79.pdf
# Saved: out/wypadek 73/WYJAŚNIENIA POSZKODOWANEGO 73.pdf.json
# Processing: data/wypadek 79/opinia 79.pdf
# Saved: out/wypadek 73/KARTA WYPADKU 73.pdf.json
# Processing: data/wypadek 79/wyjaśnienie poszkodowanego 79.pdf
# Saved: out/wypadek 73/Zawiadomienie o wypadku 73.pdf.json
# Processing: data/wypadek 63/Opinia 63.pdf
# Saved: out/wypadek 79/wyjaśnienie poszkodowanego 79.pdf.json
# Processing: data/wypadek 63/Karta wypadku 63.pdf
# Saved: out/wypadek 79/karta wypadku 79.pdf.json
# Processing: data/wypadek 63/Zawiadomienie o wypadku 63.pdf
# Saved: out/wypadek 79/zawiadomienie o wypadku 79.pdf.json
# Processing: data/wypadek 63/Wyjaśnienia poszkodowanego 63.pdf
# Saved: out/wypadek 63/Opinia 63.pdf.json
# Processing: data/wypadek 7/zawiadomienie o wypadku 7.pdf
# Saved: out/wypadek 79/opinia 79.pdf.json
# Processing: data/wypadek 7/karta wypadku 7.pdf
# Saved: out/wypadek 63/Karta wypadku 63.pdf.json
# Processing: data/wypadek 7/opinia 7.pdf
# Saved: out/wypadek 7/karta wypadku 7.pdf.json
# Processing: data/wypadek 7/wyjaśnienia poszkodowanego 7.pdf
# Saved: out/wypadek 63/Wyjaśnienia poszkodowanego 63.pdf.json
# Processing: data/wypadek 10/zawiadomienie o wypadku 10.pdf
# Saved: out/wypadek 63/Zawiadomienie o wypadku 63.pdf.json
# Processing: data/wypadek 10/opinia 10.pdf
# Saved: out/wypadek 7/zawiadomienie o wypadku 7.pdf.json
# Processing: data/wypadek 10/wyjaśnienia poszkodowanego 10.pdf
# Saved: out/wypadek 7/opinia 7.pdf.json
# Processing: data/wypadek 10/karta wypadku 10.pdf
# Saved: out/wypadek 10/opinia 10.pdf.json
# Processing: data/wypadek 92/opinia 92.pdf
# Saved: out/wypadek 7/wyjaśnienia poszkodowanego 7.pdf.json
# Processing: data/wypadek 92/wyjaśnienia poszkodowanego 92.pdf
# Saved: out/wypadek 10/zawiadomienie o wypadku 10.pdf.json
# Processing: data/wypadek 92/karta wypadku 92.pdf
# Saved: out/wypadek 10/wyjaśnienia poszkodowanego 10.pdf.json
# Processing: data/wypadek 92/zawiadomienie o wypadku 92.pdf
# Saved: out/wypadek 10/karta wypadku 10.pdf.json
# Processing: data/wypadek 8/zawiadomienie o wypadku 8.pdf
# Saved: out/wypadek 92/wyjaśnienia poszkodowanego 92.pdf.json
# Processing: data/wypadek 8/karta wypadku 8.pdf
# Saved: out/wypadek 92/opinia 92.pdf.json
# Processing: data/wypadek 8/opinia 8.pdf
# Saved: out/wypadek 92/karta wypadku 92.pdf.json
# Processing: data/wypadek 8/wyjaśnienia poszkodowanego 8.pdf
# Saved: out/wypadek 92/zawiadomienie o wypadku 92.pdf.json
# Processing: data/wypadek 65/Opinia 65.pdf
# Saved: out/wypadek 8/opinia 8.pdf.json
# Processing: data/wypadek 65/Zawiadomienie o wypadku 65.pdf
# Saved: out/wypadek 8/karta wypadku 8.pdf.json
# Processing: data/wypadek 65/Wyjaśnienia poszkodowanego 65.pdf
# Saved: out/wypadek 8/zawiadomienie o wypadku 8.pdf.json
# Processing: data/wypadek 65/Karta wypadku 65.pdf
# Saved: out/wypadek 65/Opinia 65.pdf.json
# Processing: data/wypadek 44/karta wypadku 44.pdf
# Saved: out/wypadek 65/Zawiadomienie o wypadku 65.pdf.json
# Processing: data/wypadek 44/opinia 44.pdf
# Saved: out/wypadek 65/Wyjaśnienia poszkodowanego 65.pdf.json
# Processing: data/wypadek 44/zawiadomienie o wypadku 44.pdf
# Saved: out/wypadek 65/Karta wypadku 65.pdf.json
# Processing: data/wypadek 44/wyjaśnienia poszkodowanego 44.pdf
# Saved: out/wypadek 44/karta wypadku 44.pdf.json
# Processing: data/wypadek 16/karta wypadku 16.pdf
# Saved: out/wypadek 44/opinia 44.pdf.json
# Processing: data/wypadek 16/opinia 16.pdf
# Saved: out/wypadek 44/wyjaśnienia poszkodowanego 44.pdf.json
# Processing: data/wypadek 16/zawiadomienie o wypadku 16.pdf
# Saved: out/wypadek 44/zawiadomienie o wypadku 44.pdf.json
# Processing: data/wypadek 16/wyjaśnienia poszkodowanego 16.pdf
# Saved: out/wypadek 16/opinia 16.pdf.json
# Processing: data/wypadek 88/wyjaśnienia poszkodowanego 88.pdf
# Saved: out/wypadek 16/karta wypadku 16.pdf.json
# Processing: data/wypadek 88/karta wypadku 88.pdf
# Saved: out/wypadek 16/wyjaśnienia poszkodowanego 16.pdf.json
# Processing: data/wypadek 88/opinia 88.pdf
# Saved: out/wypadek 16/zawiadomienie o wypadku 16.pdf.json
# Processing: data/wypadek 88/zawiadomienie o wypadku 88.pdf
# Saved: out/wypadek 88/wyjaśnienia poszkodowanego 88.pdf.json
# Processing: data/wypadek 13/wyjaśnienia poszkodowanego 13.pdf
# Saved: out/wypadek 88/karta wypadku 88.pdf.json
# Processing: data/wypadek 13/zawiadomienie o wypadku13.pdf
# Saved: out/wypadek 88/opinia 88.pdf.json
# Processing: data/wypadek 13/karta wypadku 13.pdf
# Saved: out/wypadek 88/zawiadomienie o wypadku 88.pdf.json
# Processing: data/wypadek 13/opinia 13.pdf
# Saved: out/wypadek 13/wyjaśnienia poszkodowanego 13.pdf.json
# Processing: data/wypadek 57/karta wypadku 57.pdf
# Saved: out/wypadek 13/zawiadomienie o wypadku13.pdf.json
# Processing: data/wypadek 57/wyjaśnienia poszkodowanego 57.pdf
# Saved: out/wypadek 13/karta wypadku 13.pdf.json
# Processing: data/wypadek 57/zawiadomienie o wypadku 57.pdf
# Saved: out/wypadek 13/opinia 13.pdf.json
# Processing: data/wypadek 57/opinia 57.pdf
# Saved: out/wypadek 57/karta wypadku 57.pdf.json
# Processing: data/wypadek 17/zawiadomienie o wypadku 17.pdf
# Saved: out/wypadek 57/wyjaśnienia poszkodowanego 57.pdf.json
# Processing: data/wypadek 17/wyjaśnienia poszkodowanego 17.pdf
# Saved: out/wypadek 57/opinia 57.pdf.json
# Processing: data/wypadek 17/opinia 17.pdf
# Saved: out/wypadek 57/zawiadomienie o wypadku 57.pdf.json
# Processing: data/wypadek 17/karta wypadku 17.pdf
# Saved: out/wypadek 17/zawiadomienie o wypadku 17.pdf.json
# Processing: data/wypadek 3/karta wypadku 3.pdf
# Saved: out/wypadek 17/wyjaśnienia poszkodowanego 17.pdf.json
# Processing: data/wypadek 3/wyjaśnienia poszkodowanego 3.pdf
# Saved: out/wypadek 17/opinia 17.pdf.json
# Processing: data/wypadek 3/opinia  3.pdf
# Saved: out/wypadek 3/karta wypadku 3.pdf.json
# Processing: data/wypadek 3/zawiadomienie o wypadku 3.pdf
# Saved: out/wypadek 17/karta wypadku 17.pdf.json
# Processing: data/wypadek 61/wyjaśnienia poszkodowanego 61.pdf
# Saved: out/wypadek 3/wyjaśnienia poszkodowanego 3.pdf.json
# Processing: data/wypadek 61/karta wypadku 61.pdf
# Saved: out/wypadek 3/opinia  3.pdf.json
# Processing: data/wypadek 61/zawiadomienie o wypadku 61.pdf
# Saved: out/wypadek 3/zawiadomienie o wypadku 3.pdf.json
# Processing: data/wypadek 61/opinia 61.pdf
# Saved: out/wypadek 61/karta wypadku 61.pdf.json
# Processing: data/wypadek 104/wyjaśnienia poszkodowanego 104.pdf
# Saved: out/wypadek 8/wyjaśnienia poszkodowanego 8.pdf.json
# Processing: data/wypadek 104/karta wypadku 104.pdf
# Saved: out/wypadek 61/wyjaśnienia poszkodowanego 61.pdf.json
# Processing: data/wypadek 104/opinia 104.pdf
# Saved: out/wypadek 61/zawiadomienie o wypadku 61.pdf.json
# Processing: data/wypadek 104/zawiadomienie o wypadku 104.pdf
# Saved: out/wypadek 61/opinia 61.pdf.json
# Processing: data/wypadek 21/opinia 21.pdf
# Saved: out/wypadek 104/wyjaśnienia poszkodowanego 104.pdf.json
# Processing: data/wypadek 21/karta wypadku 21.pdf
# Saved: out/wypadek 104/karta wypadku 104.pdf.json
# Processing: data/wypadek 21/zawiadomienie o wypadku 21.pdf
# Saved: out/wypadek 104/opinia 104.pdf.json
# Processing: data/wypadek 21/wyjaśnienia poszkodowanego 21.pdf
# Saved: out/wypadek 104/zawiadomienie o wypadku 104.pdf.json
# Processing: data/wypadek 4/zawiadomienie o wypadku 4.pdf
# Saved: out/wypadek 21/opinia 21.pdf.json
# Processing: data/wypadek 4/karta wypadku 4.pdf
# Saved: out/wypadek 21/karta wypadku 21.pdf.json
# Processing: data/wypadek 4/wyjaśnienia poszkodowanego 4.pdf
# Saved: out/wypadek 21/zawiadomienie o wypadku 21.pdf.json
# Processing: data/wypadek 4/opinia 4.pdf
# Saved: out/wypadek 21/wyjaśnienia poszkodowanego 21.pdf.json
# Processing: data/wypadek 108/opinia w sprawie prawnej kwalifikacji wypadku 108.pdf
# Saved: out/wypadek 4/zawiadomienie o wypadku 4.pdf.json
# Processing: data/wypadek 108/zawiadomienie o wypadku 108.pdf
# Saved: out/wypadek 4/karta wypadku 4.pdf.json
# Processing: data/wypadek 108/karta wypadku 108.pdf
# Saved: out/wypadek 4/wyjaśnienia poszkodowanego 4.pdf.json
# Processing: data/wypadek 108/zapis wyjaśnień poszkodowanego 108.pdf
# Saved: out/wypadek 108/opinia w sprawie prawnej kwalifikacji wypadku 108.pdf.json
# Processing: data/wypadek 105/wyjaśnienia poszkodowanego 105.pdf
# Saved: out/wypadek 4/opinia 4.pdf.json
# Processing: data/wypadek 105/opinia 105.pdf
# Saved: out/wypadek 108/karta wypadku 108.pdf.json
# Processing: data/wypadek 105/zawiadomienie o wypadku 105.pdf
# Saved: out/wypadek 108/zapis wyjaśnień poszkodowanego 108.pdf.json
# Processing: data/wypadek 105/karta wypadku 105.pdf
# Saved: out/wypadek 108/zawiadomienie o wypadku 108.pdf.json
# Processing: data/wypadek 91/wyjaśnienia poszkodowanego 91.pdf
# Saved: out/wypadek 105/wyjaśnienia poszkodowanego 105.pdf.json
# Processing: data/wypadek 91/kart wypadku 91.pdf
# Saved: out/wypadek 105/opinia 105.pdf.json
# Processing: data/wypadek 91/zawiadomienie o wypadku 91.pdf
# Saved: out/wypadek 105/zawiadomienie o wypadku 105.pdf.json
# Processing: data/wypadek 91/opinia 91.pdf
# Saved: out/wypadek 105/karta wypadku 105.pdf.json
# Processing: data/wypadek 62/Zawaidomienie o wypadku 62.pdf
# Saved: out/wypadek 91/wyjaśnienia poszkodowanego 91.pdf.json
# Processing: data/wypadek 62/Opinia 62.pdf
# Saved: out/wypadek 91/kart wypadku 91.pdf.json
# Processing: data/wypadek 62/Wyjaśnienia poszkodowanego 62.pdf
# Saved: out/wypadek 91/zawiadomienie o wypadku 91.pdf.json
# Processing: data/wypadek 62/Karta wypadku 62.pdf
# Saved: out/wypadek 91/opinia 91.pdf.json
# Processing: data/wypadek 96/zawiadomienie o wypadku 96.pdf
# Saved: out/wypadek 62/Opinia 62.pdf.json
# Processing: data/wypadek 96/karta wyp 96.pdf
# Saved: out/wypadek 62/Zawaidomienie o wypadku 62.pdf.json
# Processing: data/wypadek 96/opinia 96.pdf
# Saved: out/wypadek 62/Wyjaśnienia poszkodowanego 62.pdf.json
# Processing: data/wypadek 96/wyjaśnienia poszkodowanego 96.pdf
# Saved: out/wypadek 62/Karta wypadku 62.pdf.json
# Processing: data/wypadek 41/wyjaśnienia poszkodowanego 41.pdf
# Saved: out/wypadek 96/karta wyp 96.pdf.json
# Processing: data/wypadek 41/opinia 41.pdf
# Saved: out/wypadek 96/zawiadomienie o wypadku 96.pdf.json
# Processing: data/wypadek 41/zawiadomienie o wypadku 41.pdf
# Saved: out/wypadek 96/opinia 96.pdf.json
# Processing: data/wypadek 41/karta wypadku 41.pdf
# Saved: out/wypadek 96/wyjaśnienia poszkodowanego 96.pdf.json
# Processing: data/wypadek 107/wyjaśnienia poszkodowanego 107.pdf
# Saved: out/wypadek 41/opinia 41.pdf.json
# Processing: data/wypadek 107/zawiadomienie o wypadku 107.pdf
# Saved: out/wypadek 41/karta wypadku 41.pdf.json
# Processing: data/wypadek 107/opinia 107.pdf
# Saved: out/wypadek 41/zawiadomienie o wypadku 41.pdf.json
# Processing: data/wypadek 107/karta wypadku 107.pdf
# Saved: out/wypadek 41/wyjaśnienia poszkodowanego 41.pdf.json
# Processing: data/wypadek 11/karta wypadku 11.pdf
# Saved: out/wypadek 107/wyjaśnienia poszkodowanego 107.pdf.json
# Processing: data/wypadek 11/wyjaśnienia poszkodowanego 11.pdf
# Saved: out/wypadek 107/zawiadomienie o wypadku 107.pdf.json
# Processing: data/wypadek 11/zawiadomienie o wypadku 11.pdf
# Saved: out/wypadek 107/opinia 107.pdf.json
# Processing: data/wypadek 11/opinia 11.pdf
# Saved: out/wypadek 107/karta wypadku 107.pdf.json
# Processing: data/wypadek 64/Wyjaśnienia poszkodowanego 64.pdf
# Saved: out/wypadek 11/wyjaśnienia poszkodowanego 11.pdf.json
# Processing: data/wypadek 64/Karta wypadku 64.pdf
# Saved: out/wypadek 11/karta wypadku 11.pdf.json
# Processing: data/wypadek 64/Opinia 64.pdf
# Saved: out/wypadek 11/opinia 11.pdf.json
# Processing: data/wypadek 64/Zawiadomienie o wypadku 64.pdf
# Saved: out/wypadek 11/zawiadomienie o wypadku 11.pdf.json
# Processing: data/wypadek 34/karta wypadku 34.pdf
# Saved: out/wypadek 64/Wyjaśnienia poszkodowanego 64.pdf.json
# Processing: data/wypadek 34/zawiadomienie o wypadku 34.pdf
# Saved: out/wypadek 64/Karta wypadku 64.pdf.json
# Processing: data/wypadek 34/opinia 34.pdf
# Saved: out/wypadek 64/Opinia 64.pdf.json
# Processing: data/wypadek 34/wyjaśnienia poszkodowanego 34.pdf
# Saved: out/wypadek 64/Zawiadomienie o wypadku 64.pdf.json
# Processing: data/wypadek 83/wyjaśnienia poszkodowanego 83.pdf
# Saved: out/wypadek 34/zawiadomienie o wypadku 34.pdf.json
# Processing: data/wypadek 83/zawiadomienie o wypadku 83.pdf
# Saved: out/wypadek 34/karta wypadku 34.pdf.json
# Processing: data/wypadek 83/opinia 83.pdf
# Saved: out/wypadek 34/wyjaśnienia poszkodowanego 34.pdf.json
# Processing: data/wypadek 83/karta wypadku 83.pdf
# Saved: out/wypadek 34/opinia 34.pdf.json
# Processing: data/wypadek 35/wyjaśnienia poszkodowanego 35.pdf
# Saved: out/wypadek 83/opinia 83.pdf.json
# Processing: data/wypadek 35/karta wypadku 35.pdf
# Saved: out/wypadek 83/karta wypadku 83.pdf.json
# Processing: data/wypadek 35/opinia 35.pdf
# Saved: out/wypadek 35/wyjaśnienia poszkodowanego 35.pdf.json
# Processing: data/wypadek 35/zawiadomienie o wypadku 35.pdf
# Saved: out/wypadek 83/wyjaśnienia poszkodowanego 83.pdf.json
# Processing: data/wypadek 86/zawiadomienie o wypadku 86.pdf
# Saved: out/wypadek 83/zawiadomienie o wypadku 83.pdf.json
# Processing: data/wypadek 86/wyjaśnienia poszkodowanego 86.pdf
# Saved: out/wypadek 35/karta wypadku 35.pdf.json
# Processing: data/wypadek 86/opinia 86.pdf
# Saved: out/wypadek 35/opinia 35.pdf.json
# Processing: data/wypadek 86/karta wypadku 86.pdf
# Saved: out/wypadek 35/zawiadomienie o wypadku 35.pdf.json
# Processing: data/wypadek 43/wyjaśnienia poszkodowanego 43.pdf
# Saved: out/wypadek 86/zawiadomienie o wypadku 86.pdf.json
# Processing: data/wypadek 43/karta wypadku 43.pdf
# Saved: out/wypadek 86/wyjaśnienia poszkodowanego 86.pdf.json
# Processing: data/wypadek 43/opinia 43.pdf
# Saved: out/wypadek 86/opinia 86.pdf.json
# Processing: data/wypadek 43/zawiadomienie o wypadku 43.pdf
# Saved: out/wypadek 43/wyjaśnienia poszkodowanego 43.pdf.json
# Processing: data/wypadek 42/karta wypadku 42.pdf
# Saved: out/wypadek 43/karta wypadku 43.pdf.json
# Processing: data/wypadek 42/zawiadomienie o wypadku 42.pdf
# Saved: out/wypadek 43/opinia 43.pdf.json
# Processing: data/wypadek 42/wyjaśnienia poszkodowanego 42.pdf
# Saved: out/wypadek 86/karta wypadku 86.pdf.json
# Processing: data/wypadek 42/opinia 42.pdf
# Saved: out/wypadek 43/zawiadomienie o wypadku 43.pdf.json
# Processing: data/wypadek 1/zawiadomienie o wypadku 1.pdf
# Saved: out/wypadek 42/karta wypadku 42.pdf.json
# Processing: data/wypadek 1/wyjaśnienia poszkodowanego 1.pdf
# Saved: out/wypadek 42/zawiadomienie o wypadku 42.pdf.json
# Processing: data/wypadek 1/opinia 1.pdf
# Saved: out/wypadek 42/opinia 42.pdf.json
# Processing: data/wypadek 1/karta wypadku 1.pdf
# Saved: out/wypadek 42/wyjaśnienia poszkodowanego 42.pdf.json
# Processing: data/wypadek 87/wyjaśnienie poszkodowanego 87.pdf
# Saved: out/wypadek 1/zawiadomienie o wypadku 1.pdf.json
# Processing: data/wypadek 87/opinia 87.pdf
# Saved: out/wypadek 1/wyjaśnienia poszkodowanego 1.pdf.json
# Processing: data/wypadek 87/karta wypadku 87.pdf
# Saved: out/wypadek 1/opinia 1.pdf.json
# Processing: data/wypadek 87/zawiadomienie o wypadku 87.pdf
# Saved: out/wypadek 87/wyjaśnienie poszkodowanego 87.pdf.json
# Processing: data/wypadek 15/karta wypadku 15.pdf
# Saved: out/wypadek 1/karta wypadku 1.pdf.json
# Processing: data/wypadek 15/wyjaśnienia poszkodowanego 15.pdf
# Saved: out/wypadek 87/opinia 87.pdf.json
# Processing: data/wypadek 15/zawiadomienie o wypadku 15.pdf
# Saved: out/wypadek 87/karta wypadku 87.pdf.json
# Processing: data/wypadek 15/opinia 15.pdf
# Saved: out/wypadek 15/karta wypadku 15.pdf.json
# Processing: data/wypadek 67/Zawiadomienie o wypadku 67.pdf
# Saved: out/wypadek 15/wyjaśnienia poszkodowanego 15.pdf.json
# Processing: data/wypadek 67/Karta wypadku 67.pdf
# Saved: out/wypadek 87/zawiadomienie o wypadku 87.pdf.json
# Processing: data/wypadek 67/Opinia 67.pdf
# Saved: out/wypadek 15/zawiadomienie o wypadku 15.pdf.json
# Processing: data/wypadek 67/Wyjaśnienia poszkodowanego 67.pdf
# Saved: out/wypadek 15/opinia 15.pdf.json
# Processing: data/wypadek 49/wyjaśnienia poszkodowanego 49.pdf
# Saved: out/wypadek 67/Zawiadomienie o wypadku 67.pdf.json
# Processing: data/wypadek 49/karta wypadku 49.pdf
# Saved: out/wypadek 67/Karta wypadku 67.pdf.json
# Processing: data/wypadek 49/zawiadomienie o wypadku 49.pdf
# Saved: out/wypadek 67/Opinia 67.pdf.json
# Processing: data/wypadek 49/opinia 49.pdf
# Saved: out/wypadek 49/wyjaśnienia poszkodowanego 49.pdf.json
# Processing: data/wypadek 77/wyjaśnienie poszkodowanego 77.pdf
# Saved: out/wypadek 67/Wyjaśnienia poszkodowanego 67.pdf.json
# Processing: data/wypadek 77/opinia 77.pdf
# Saved: out/wypadek 49/karta wypadku 49.pdf.json
# Processing: data/wypadek 77/karta wypadku 77.pdf
# Saved: out/wypadek 49/opinia 49.pdf.json
# Processing: data/wypadek 77/zawiadomienie o wypadku 77.pdf
# Saved: out/wypadek 49/zawiadomienie o wypadku 49.pdf.json
# Processing: data/wypadek 25/zawiadomienie o wypadku 25.pdf
# Saved: out/wypadek 77/wyjaśnienie poszkodowanego 77.pdf.json
# Processing: data/wypadek 25/opinia 25.pdf
# Saved: out/wypadek 77/opinia 77.pdf.json
# Processing: data/wypadek 25/wyjaśnienia poszkodowanego 25.pdf
# Saved: out/wypadek 77/karta wypadku 77.pdf.json
# Processing: data/wypadek 25/karta wypadku 25.pdf
# Saved: out/wypadek 77/zawiadomienie o wypadku 77.pdf.json
# Processing: data/wypadek 55/zawiadomienie o wypadku 55.pdf
# Saved: out/wypadek 25/zawiadomienie o wypadku 25.pdf.json
# Processing: data/wypadek 55/opinia 55.pdf
# Saved: out/wypadek 25/opinia 25.pdf.json
# Processing: data/wypadek 55/wyjaśnienia poszkodowanego 55.pdf
# Saved: out/wypadek 25/wyjaśnienia poszkodowanego 25.pdf.json
# Processing: data/wypadek 55/karta wypadku 55.pdf
# Saved: out/wypadek 25/karta wypadku 25.pdf.json
# Processing: data/wypadek 72/Zawiadomienie o wypadku 72.pdf
# Saved: out/wypadek 55/opinia 55.pdf.json
# Processing: data/wypadek 72/WYJAŚNIENIA POSZKODOWANEGO 72.pdf
# Saved: out/wypadek 55/wyjaśnienia poszkodowanego 55.pdf.json
# Processing: data/wypadek 72/OPINIA 72.pdf
# Saved: out/wypadek 55/zawiadomienie o wypadku 55.pdf.json
# Processing: data/wypadek 72/KARTA WYPADKU 72.pdf
# Saved: out/wypadek 55/karta wypadku 55.pdf.json
# Processing: data/wypadek 81/zawiadomienie o wypadku 81.pdf
# Saved: out/wypadek 72/Zawiadomienie o wypadku 72.pdf.json
# Processing: data/wypadek 81/karta wypadku 81.pdf
# Saved: out/wypadek 72/WYJAŚNIENIA POSZKODOWANEGO 72.pdf.json
# Processing: data/wypadek 81/wyjaśnienie poszkodowanego 81.pdf
# Saved: out/wypadek 72/OPINIA 72.pdf.json
# Processing: data/wypadek 81/opinia 81.pdf
# Saved: out/wypadek 72/KARTA WYPADKU 72.pdf.json
# Processing: data/wypadek 18/wyjaśnienia poszkodowanego 18.pdf
# Saved: out/wypadek 81/zawiadomienie o wypadku 81.pdf.json
# Processing: data/wypadek 18/zawiadomienie o wypadku 18.pdf
# Saved: out/wypadek 81/karta wypadku 81.pdf.json
# Processing: data/wypadek 18/opinia 18.pdf
# Saved: out/wypadek 81/opinia 81.pdf.json
# Processing: data/wypadek 18/karta wypadku 18.pdf
# Saved: out/wypadek 81/wyjaśnienie poszkodowanego 81.pdf.json
# Processing: data/wypadek 71/OPINIA 71.pdf
# Saved: out/wypadek 18/wyjaśnienia poszkodowanego 18.pdf.json
# Processing: data/wypadek 71/KARTA WYPADKU 71.pdf
# Saved: out/wypadek 18/zawiadomienie o wypadku 18.pdf.json
# Processing: data/wypadek 71/WYJAŚNIENIA POSZKODOWANEGO 71 (2).pdf
# Saved: out/wypadek 18/opinia 18.pdf.json
# Processing: data/wypadek 71/Zawiadomienie o wypadku 71.pdf
# Saved: out/wypadek 18/karta wypadku 18.pdf.json
# Processing: data/wypadek 71/WYJAŚNIENIA POSZKODOWANEGO 71.pdf
# Saved: out/wypadek 71/OPINIA 71.pdf.json
# Processing: data/wypadek 98/karta wypadku 98.pdf
# Saved: out/wypadek 71/KARTA WYPADKU 71.pdf.json
# Processing: data/wypadek 98/zawiadomienie o wypadku 98.pdf
# Saved: out/wypadek 71/Zawiadomienie o wypadku 71.pdf.json
# Processing: data/wypadek 98/opinia 98.pdf
# Saved: out/wypadek 98/karta wypadku 98.pdf.json
# Processing: data/wypadek 98/wyjaśnienia poszkodowanego 98.pdf
# Saved: out/wypadek 71/WYJAŚNIENIA POSZKODOWANEGO 71 (2).pdf.json
# Processing: data/wypadek 29/wyjaśnienia poszkodowanego 29.pdf
# Saved: out/wypadek 71/WYJAŚNIENIA POSZKODOWANEGO 71.pdf.json
# Processing: data/wypadek 29/zawiadomienie o wypadku 29.pdf
# Saved: out/wypadek 98/zawiadomienie o wypadku 98.pdf.json
# Processing: data/wypadek 29/karta wypadku 29.pdf
# Saved: out/wypadek 98/opinia 98.pdf.json
# Processing: data/wypadek 29/opinia 29.pdf
# Saved: out/wypadek 98/wyjaśnienia poszkodowanego 98.pdf.json
# Processing: data/wypadek 60/opinia 60.pdf
# Saved: out/wypadek 29/wyjaśnienia poszkodowanego 29.pdf.json
# Processing: data/wypadek 60/karta wypadku 60.pdf
# Saved: out/wypadek 29/zawiadomienie o wypadku 29.pdf.json
# Processing: data/wypadek 60/zawiadomienie o wypadku 60.pdf
# Saved: out/wypadek 29/karta wypadku 29.pdf.json
# Processing: data/wypadek 60/wyjaśnienia poszkodowanego 60.pdf
# Saved: out/wypadek 29/opinia 29.pdf.json
# Processing: data/wypadek 82/karta wypadku 82.pdf
# Saved: out/wypadek 60/opinia 60.pdf.json
# Processing: data/wypadek 82/opinia 82.pdf
# Saved: out/wypadek 60/karta wypadku 60.pdf.json
# Processing: data/wypadek 82/zawiadomienie o wypadku 82.pdf
# Saved: out/wypadek 60/zawiadomienie o wypadku 60.pdf.json
# Processing: data/wypadek 82/wyjaśnienie poszkodowanego 82.pdf
# Saved: out/wypadek 82/opinia 82.pdf.json
# Processing: data/wypadek 53/wyjaśnienia poszkodowanego 53.pdf
# Saved: out/wypadek 60/wyjaśnienia poszkodowanego 60.pdf.json
# Processing: data/wypadek 53/karta wypadku 53.pdf
# Saved: out/wypadek 82/karta wypadku 82.pdf.json
# Processing: data/wypadek 53/opinia 53.pdf
# Saved: out/wypadek 82/zawiadomienie o wypadku 82.pdf.json
# Processing: data/wypadek 53/zawiadomienie o wypadku 53.pdf
# Saved: out/wypadek 82/wyjaśnienie poszkodowanego 82.pdf.json
# Processing: data/wypadek 32/opinia 32.pdf
# Saved: out/wypadek 53/wyjaśnienia poszkodowanego 53.pdf.json
# Processing: data/wypadek 32/wyjaśnienia poszkodowanego 32.pdf
# Saved: out/wypadek 53/opinia 53.pdf.json
# Processing: data/wypadek 32/zawiadomienie o wypadku 32.pdf
# Saved: out/wypadek 53/zawiadomienie o wypadku 53.pdf.json
# Processing: data/wypadek 32/karta wypadku 32.pdf
# Saved: out/wypadek 32/opinia 32.pdf.json
# Processing: data/wypadek 26/karta wypadku 26.pdf
# Saved: out/wypadek 53/karta wypadku 53.pdf.json
# Processing: data/wypadek 26/opinia 26.pdf
# Saved: out/wypadek 32/wyjaśnienia poszkodowanego 32.pdf.json
# Processing: data/wypadek 26/wyjśnienia poszkodowanego 26.pdf
# Saved: out/wypadek 32/karta wypadku 32.pdf.json
# Processing: data/wypadek 26/zawiadomienie o wypadku 26.pdf
# Saved: out/wypadek 26/karta wypadku 26.pdf.json
# Processing: data/wypadek 9/wyjaśnienia poszkodowanego 9.pdf
# Saved: out/wypadek 26/opinia 26.pdf.json
# Processing: data/wypadek 9/zawiadomienie o wypadku 9.pdf
# Saved: out/wypadek 26/wyjśnienia poszkodowanego 26.pdf.json
# Processing: data/wypadek 9/opinia 9.pdf
# Saved: out/wypadek 26/zawiadomienie o wypadku 26.pdf.json
# Processing: data/wypadek 9/karta wypadku 9.pdf
# Saved: out/wypadek 9/wyjaśnienia poszkodowanego 9.pdf.json
# Processing: data/wypadek 54/opinia 54.pdf
# Saved: out/wypadek 9/opinia 9.pdf.json
# Processing: data/wypadek 54/wyjaśnienia poszkodowanego 54.pdf
# Saved: out/wypadek 9/zawiadomienie o wypadku 9.pdf.json
# Processing: data/wypadek 54/zawiadomienie o wypadku 54.pdf
# Saved: out/wypadek 9/karta wypadku 9.pdf.json
# Processing: data/wypadek 54/karta wypadku 54.pdf
# Saved: out/wypadek 54/opinia 54.pdf.json
# Processing: data/wypadek 76/WYJAŚNIENIA POSZKODOWANEGO 76.pdf
# Saved: out/wypadek 54/wyjaśnienia poszkodowanego 54.pdf.json
# Processing: data/wypadek 76/OPINIA 76.pdf
# Saved: out/wypadek 54/zawiadomienie o wypadku 54.pdf.json
# Processing: data/wypadek 76/Zawiadomienie o wypadku 76.pdf
# Saved: out/wypadek 54/karta wypadku 54.pdf.json
# Processing: data/wypadek 76/KARTA WYPADKU 76.pdf
# Saved: out/wypadek 76/WYJAŚNIENIA POSZKODOWANEGO 76.pdf.json
# Processing: data/wypadek 50/wyjaśnienia poszkodowanego 50.pdf
# Saved: out/wypadek 76/OPINIA 76.pdf.json
# Processing: data/wypadek 50/zawiadomienie o wypadku 50.pdf
# Saved: out/wypadek 32/zawiadomienie o wypadku 32.pdf.json
# Processing: data/wypadek 50/opinia 50.pdf
# Saved: out/wypadek 76/Zawiadomienie o wypadku 76.pdf.json
# Processing: data/wypadek 50/karta wypadku 50.pdf
# Saved: out/wypadek 76/KARTA WYPADKU 76.pdf.json
# Processing: data/wypadek 39/zawiadomienie o wypadku 39.pdf
# Saved: out/wypadek 50/wyjaśnienia poszkodowanego 50.pdf.json
# Processing: data/wypadek 39/opinia 39.pdf
# Saved: out/wypadek 50/zawiadomienie o wypadku 50.pdf.json
# Processing: data/wypadek 39/karta wypadku 39.pdf
# Saved: out/wypadek 50/opinia 50.pdf.json
# Processing: data/wypadek 39/wyjaśnienia poszkodowanego 39.pdf
# Saved: out/wypadek 50/karta wypadku 50.pdf.json
# Processing: data/wypadek 27/karta wypadku 27.pdf
# Saved: out/wypadek 39/zawiadomienie o wypadku 39.pdf.json
# Processing: data/wypadek 27/zawiadomienie o wypadku 27.pdf
# Saved: out/wypadek 39/opinia 39.pdf.json
# Processing: data/wypadek 27/opinia 27.pdf
# Saved: out/wypadek 39/karta wypadku 39.pdf.json
# Processing: data/wypadek 27/wyjaśnienia poszkodowanego 27.pdf
# Saved: out/wypadek 39/wyjaśnienia poszkodowanego 39.pdf.json
# Processing: data/wypadek 47/opinia 47.pdf
# Saved: out/wypadek 27/opinia 27.pdf.json
# Processing: data/wypadek 47/zawiadomienie o wypadku 47.pdf
# Saved: out/wypadek 27/zawiadomienie o wypadku 27.pdf.json
# Processing: data/wypadek 47/wyjaśnienia poszkodowanego 47.pdf
# Saved: out/wypadek 27/wyjaśnienia poszkodowanego 27.pdf.json
# Processing: data/wypadek 47/karta wypadku 47.pdf
# Saved: out/wypadek 27/karta wypadku 27.pdf.json
# Processing: data/wypadek 12/wyjaśnienia poszkodowanego 12.pdf
# Saved: out/wypadek 47/opinia 47.pdf.json
# Processing: data/wypadek 12/karta wypadku 12.pdf
# Saved: out/wypadek 47/wyjaśnienia poszkodowanego 47.pdf.json
# Processing: data/wypadek 12/opinia 12.pdf
# Saved: out/wypadek 47/zawiadomienie o wypadku 47.pdf.json
# Processing: data/wypadek 12/zawiadomienie o wypadku 12.pdf
# Saved: out/wypadek 47/karta wypadku 47.pdf.json
# Processing: data/wypadek 70/WYJAŚNIENIA POSZKODOWANEGO 70.pdf
# Saved: out/wypadek 12/wyjaśnienia poszkodowanego 12.pdf.json
# Processing: data/wypadek 70/KARTA WYPADKU 70.pdf
# Saved: out/wypadek 12/karta wypadku 12.pdf.json
# Processing: data/wypadek 70/OPINIA 70.pdf
# Saved: out/wypadek 70/OPINIA 70.pdf.json
# Processing: data/wypadek 70/Zawiadomienie o wypadku 70.pdf
# Saved: out/wypadek 12/opinia 12.pdf.json
# Saved: out/wypadek 70/KARTA WYPADKU 70.pdf.json
# Saved: out/wypadek 12/zawiadomienie o wypadku 12.pdf.json
# Saved: out/wypadek 70/WYJAŚNIENIA POSZKODOWANEGO 70.pdf.json
# Saved: out/wypadek 70/Zawiadomienie o wypadku 70.pdf.json
#
# Completed: 445/445 files

# %%
# Podsumowanie
print(f"\nProcessed {len(results)} files")
print("\nFirst 5 results:")
for path, out_path in list(results.items())[:5]:
    print(f"  {Path(path).name} -> {out_path}")
